# %%
# On opening a New file, Rename the file and give a relevant meaningful name.

# %%
#print Statement
# Using print statement print HOPE AI

# Syntax print().The text to be printed should be typed inside the brackets withing double quotes ""
# After typing the print statement press Shift button + Control Button to execute the program. 
# On executing the code you will get the output below this line. On the left side of this line there is a
# closed bracket. First it will be empty. On execution a number will be displayed. This number shows how many times this code line has been executed.
print("Hope AI")
# Out:
# Hope AI

# %%
# Task: Buy Input
# Enter your institute name? : HOPE AI

# This assignment is to get the input from the user dynamically at the time of using.
# Syntax input(). This input() statement will ask for the input at the time of executing the code.
# We can also add some meaningful text within quotes inside the brackets. Ex: "Enter your institute Name? :
# The input to be typed is HOPE AI

input("Enter your institute Name? :")
# Out:
# Enter your institute Name? : HOPE AI
# 'HOPE AI'

# %%
# Task: Buy Inputs. Here you have to buy multiple inputs dynamically.
input("Enter your name: ")
input("Enter your age: ")
input("Enter your school name: ")
input("Enter your drgree: ")
# Out:
# Enter your name:  Raj
# Enter your age:  15
# Enter your school name:  Guru School
# Enter your drgree:  B.E CSE
# 'B.E CSE'

# %%
# Task: Addtion

# CODE STEPS
# Get number inputs from the user for two variables a and b. use input() statement. declare this as integer input.
# Add these two variables using another variable "add"
# Display the result using print() statement.

# CODE
a=int(input("Enter number a "))
b=int(input("Enter number b "))
add=a + b
print("a=",a)
print("b=",b)
print("add= ",add)
# Out:
# Enter number a  43
# Enter number b  34
# a= 43
# b= 34
# add=  77

# %%
# Task: Substraction
a=int(input("Enter number a "))
b=int(input("Enter number b "))
sub=a - b
print("a=",a)
print("b=",b)
print("Sub= ",sub)
# Out:
# Enter number a  43
# Enter number b  34
# a= 43
# b= 34
# Sub=  9

# %%
# Task: Multiplication
a=int(input("Enter number a "))
b=int(input("Enter number b "))
mul=a * b
print("a=",a)
print("b=",b)
print("mul= ",mul)
# Out:
# Enter number a  63
# Enter number b  97
# a= 63
# b= 97
# mul=  6111

# %%
# Task: Float Division. 
a=int(input("Enter number a "))
b=int(input("Enter number b "))
float_div=a / b
print("a=",a)
print("b=",b)
print("Float Div= ",float_div)
# Out:
# Enter number a  76
# Enter number b  31
# a= 76
# b= 31
# Float Div=  2.4516129032258065

# %%
# Task: Floor Division
a=int(input("Enter number a "))
b=int(input("Enter number b "))
floor_div=a // b
print("a=",a)
print("b=",b)
print("Floor Div= ",floor_div)
# Out:
# Enter number a  76
# Enter number b  31
# a= 76
# b= 31
# Floor Div=  2

# %%
# Task: Modulo
a=int(input("Enter number a "))
b=int(input("Enter number b "))
modulo=a % b
print("a=",a)
print("b=",b)
print("Modulo= ",modulo)
# Out:
# Enter number a  76
# Enter number b  31
# a= 76
# b= 31
# Modulo=  14

# %%
# Task: Power
base=int(input("Enter Base number a "))
exponent=int(input("Enter Exponent number b "))
power=base ** exponent
print("a=",base)
print("b=",exponent)
print("Power= ",power)
# Out:
# Enter Base number a  4
# Enter Exponent number b  4
# a= 4
# b= 4
# Power=  256
