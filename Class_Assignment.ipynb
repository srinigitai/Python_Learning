# %%
# Importing the .py file created for class.
# Syntax : from ".py filename" import "class name". from and import are key words.
# after importing the file do the execution. If there is no error then it is working.

# This file name "arithmetic_operator.py" file has class name "arithmetic_operator".
# Under the class "arithmetic_operator" four functions are there. 
# function "addition", function "substraction", function "multiplication", function "division"

from arithmetic_operator import arithmetic_operator

# %%
# calling the addition function inside the arithmetic_operator class.
arithmetic_operator.addition()
# Out:
# Enter Number1 :  100
# Enter Number2 : 500
# 600

# %%
# calling the division function inside the arithmetic_operator class.
arithmetic_operator.division()
# Out:
# Enter Number1 :  225
# Enter Number2 :  5
# 45.0

# %%
# calling the multiplication function inside the arithmetic_operator class.
arithmetic_operator.multiplication()
# Out:
# Enter Number1 :  1234
# Enter Number2 :  1234
# 1522756

# %%
# calling the substraction function inside the arithmetic_operator class.
arithmetic_operator.substraction()
# Out:
# Enter Number1 :  1256
# Enter Number2 :  100
# 1156
